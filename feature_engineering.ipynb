# %%
"""
FEATURE ENGINEERING – ASSIGNMENT ANSWERS
1. What is a parameter?

A parameter is a value used by a model during training to make predictions. These values are learned automatically from the data. Example: weights in Linear Regression.

2. What is correlation?

Correlation measures the relationship between two variables. It shows how one variable changes with respect to another.

3. What does negative correlation mean?

Negative correlation means when one variable increases, the other decreases. Example: As price increases, demand decreases.

4. Define Machine Learning. What are the main components?

Machine Learning is a method of teaching computers to learn patterns from data and make decisions without explicit programming.

Main components:

Data
Model
Training
Evaluation
5. How does loss value help in determining model performance?

Loss value shows how much error the model is making. Lower loss means better model performance.

6. What are continuous and categorical variables?
Continuous variables: Numeric values (e.g., height, weight)
Categorical variables: Categories (e.g., gender, color)
7. How do we handle categorical variables? Techniques?

Common techniques:

Label Encoding
One Hot Encoding
8. What do you mean by training and testing a dataset?
Training dataset: Used to train the model
Testing dataset: Used to check model performance
9. What is sklearn.preprocessing?

It is a module in Python used for data preprocessing like scaling and encoding.

10. What is a Test set?

A test set is a part of the dataset used to evaluate the model after training.

11. How do we split data in Python?

Using train_test_split() from sklearn
Example:

from sklearn.model_selection import train_test_split
12. How do you approach a ML problem?

Steps:

Understand problem
Collect data
Clean data
Perform EDA
Train model
Evaluate model
13. Why perform EDA?

EDA helps understand data patterns, relationships, and detect issues before modeling.

14. How can you find correlation in Python?

Using:

data.corr()
15. What is causation? Difference from correlation?
Correlation: Variables are related
Causation: One variable directly affects another

Example:
Ice cream sales and temperature are correlated, but temperature causes sales increase.

16. What is an Optimizer? Types?

Optimizer helps improve model performance by reducing error.

Types:

Gradient Descent
Adam
17. What is sklearn.linear_model?

It is a module used for linear models like Linear Regression.

18. What does model.fit() do?

It trains the model using data.

Arguments: X (features), y (target)

19. What does model.predict() do?

It makes predictions using trained model.

Argument: X (input data)

20. What is feature scaling?

Feature scaling standardizes data so all features are in similar range.

21. How do we perform scaling in Python?

Using StandardScaler:

from sklearn.preprocessing import StandardScaler
22. How do we split data?

Using train_test_split()

23. Explain data encoding?

Data encoding converts categorical data into numeric form."""
# Out:
# '\nFEATURE ENGINEERING – ASSIGNMENT ANSWERS\n1. What is a parameter?\n\nA parameter is a value used by a model during training to make predictions. These values are learned automatically from the data. Example: weights in Linear Regression.\n\n2. What is correlation?\n\nCorrelation measures the relationship between two variables. It shows how one variable changes with respect to another.\n\n3. What does negative correlation mean?\n\nNegative correlation means when one variable increases, the other decreases. Example: As price increases, demand decreases.\n\n4. Define Machine Learning. What are the main components?\n\nMachine Learning is a method of teaching computers to learn patterns from data and make decisions without explicit programming.\n\nMain components:\n\nData\nModel\nTraining\nEvaluation\n5. How does loss value help in determining model performance?\n\nLoss value shows how much error the model is making. Lower loss means better model performance.\n\n6. What are continuous 
# ...
