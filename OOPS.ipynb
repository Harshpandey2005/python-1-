# %%
"""
1. Five key concepts of OOP

The five key concepts of Object-Oriented Programming are:

Encapsulation – Wrapping data and methods together
Abstraction – Hiding implementation details
Inheritance – Acquiring properties from another class
Polymorphism – Same method, different behavior
Class & Object – Blueprint and its instance
"""
# Out:
# '\n1. Five key concepts of OOP\n\nThe five key concepts of Object-Oriented Programming are:\n\nEncapsulation – Wrapping data and methods together\nAbstraction – Hiding implementation details\nInheritance – Acquiring properties from another class\nPolymorphism – Same method, different behavior\nClass & Object – Blueprint and its instance\n'

# %%
#2. Python class for Car
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def display_info(self):
        print(f"{self.year} {self.make} {self.model}")

car1 = Car("Toyota", "Corolla", 2020)
car1.display_info()
# Out:
# 2020 Toyota Corolla

# %%
#3. Instance vs Class Method
#Instance Method → Works on object data (self)
#Class Method → Works on class data (cls)
class Example:
    def instance_method(self):
        print("Instance Method")

    @classmethod
    def class_method(cls):
        print("Class Method")

# %%
#4. Method Overloading in Python

#Python does not support traditional overloading. It uses default arguments.

def add(a, b=0, c=0):
    return a + b + c

print(add(5))
print(add(5, 3))
print(add(5, 3, 2))
# Out:
# 5
# 8
# 10

# %%
"""
5. Access Modifiers in Python
Public → self.name
Protected → self._name
Private → self.__name
"""
# Out:
# '\n5. Access Modifiers in Python\nPublic → self.name\nProtected → self._name\nPrivate → self.__name\n'

# %%
"""
6. Types of Inheritance
Single
Multiple
Multilevel
Hierarchical
Hybrid

Multiple Inheritance Example:
"""
class A:
    def showA(self):
        print("A")

class B:
    def showB(self):
        print("B")

class C(A, B):
    pass

obj = C()
obj.showA()
obj.showB()
# Out:
# A
# B

# %%
#7. Method Resolution Order (MRO)

#MRO decides the order in which methods are searched.

class A: pass
class B(A): pass

print(B.mro())
# Out:
# [<class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
#8. Abstract Class Shape
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        return math.pi * self.r * self.r

class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b
    def area(self):
        return self.l * self.b

# %%
#9. Polymorphism Example
def print_area(shape):
    print(shape.area())

c = Circle(5)
r = Rectangle(4, 6)

print_area(c)
print_area(r)
# Out:
# 78.53981633974483
# 24

# %%
#10. Encapsulation (BankAccount)
class BankAccount:
    def __init__(self, acc_no, balance):
        self.__account_number = acc_no
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount

    def get_balance(self):
        return self.__balance

# %%
#11. Magic Methods (str and add)
class Number:
    def __init__(self, value):
        self.value = value

    def __str__(self):
        return f"Value is {self.value}"

    def __add__(self, other):
        return self.value + other.value

n1 = Number(5)
n2 = Number(3)

print(n1)
print(n1 + n2)
# Out:
# Value is 5
# 8

# %%
#12. Decorator for Execution Time
import time

def timer(func):
    def wrapper():
        start = time.time()
        func()
        end = time.time()
        print("Time:", end - start)
    return wrapper

@timer
def test():
    for i in range(1000000):
        pass

test()
# Out:
# Time: 0.029889822006225586

# %%
"""
13. Diamond Problem

It occurs in multiple inheritance when two classes inherit from same base class.

👉 Python solves it using MRO (Method Resolution Order)
"""
# Out:
# '\n13. Diamond Problem\n\nIt occurs in multiple inheritance when two classes inherit from same base class.\n\n👉 Python solves it using MRO (Method Resolution Order)\n'

# %%
#14. Count Number of Objects
class Counter:
    count = 0

    def __init__(self):
        Counter.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

a = Counter()
b = Counter()
print(Counter.get_count())
# Out:
# 2

# %%
#15. Static Method (Leap Year)
class Year:
    @staticmethod
    def is_leap(year):
        return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print(Year.is_leap(2024))
# Out:
# True
